# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Operations_Research/blob/main/ClassWork/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 3

# %% [markdown]
# ## 0 Ball Drop Better Solution
#
# 14 drops!
#
# Show the mathematical formula too

# %% [markdown]
# ## 1 Maximize the function:
#
# $$ f(x) = a\ln\left(\frac a x\right) -a +x$$

# %% [markdown]
# ## 2 Create a box out of 24in by 36 in cardboard that maximizes volume.

# %% [markdown]
# ## 3 Max area rectangle inside $\frac{x^2}4 +y^2 = 1$.

# %% [markdown]
# ## 4 Exam Problem From Last Time:
#
# > You have 10 identical cartons each holding 10 water bottles.  All water bottles weight 10 oz. each except for one defective carton in which each of the 10 bottles weights 9 oz.  A scale is available for weighing.  Suggest a method for locating the defective carton.  Suggest an improvement on your method to minimize the number of weightings.

# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Operations_Research/blob/main/ClassWork/090225.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gameswon = [105,102,113,85,112,86,91,102]

# %%
len(gameswon)
# Out:
# 8

# %%
battingavg = [279,268,264,277,290,274,285,272]

from scipy import stats

stats.linregress(gameswon,battingavg)
# Out:
# LinregressResult(slope=np.float64(-0.07624113475177305), intercept=np.float64(283.7109929078014), rvalue=np.float64(-0.09772903953889636), pvalue=np.float64(0.8179214660799774), stderr=np.float64(0.3169612437275531), intercept_stderr=np.float64(31.705631784169274))

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Reshape the data for scikit-learn
X = np.array(battingavg).reshape(-1, 1)
y = np.array(gameswon)

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Print the coefficients
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_[0])
# Out:
# Intercept: 134.09104151493082
# Coefficient: -0.12527312454479245
